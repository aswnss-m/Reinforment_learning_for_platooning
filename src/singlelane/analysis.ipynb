# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../simple_platooning.csv")

# %%
df = pd.DataFrame(df)

# %%
df = df.dropna(axis=0)

# %%
plt.plot(df.headway)
